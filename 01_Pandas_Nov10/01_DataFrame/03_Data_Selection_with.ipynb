# %% [markdown]
# <a href="https://colab.research.google.com/github/MANOJKUMARKONDURU/05_Machine-Learning_Nov10_2025/blob/main/01_Pandas_Nov10/01_DataFrame/03_Data_Selection_with.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #3.Data Selection
#
# * means extracting elements, rows, columns or subsets from such an object.
#
# * data selection allows us to work on just a portion of a dataset

# %% [markdown]
# #Indexing
# the row index and column index - to access, or select specific parts of the data
#
# * row indexer : a value

# %%
import pandas as pd

# %%
data = pd.read_csv('Lending-company.csv', index_col = 'StringID')
lending_co_data = data.copy()
lending_co_data.head()
# Out:
#           LoanID    Product CustomerGender     Location    Region  TotalPrice  \
# StringID
# LoanID_1       1  Product B         Female   Location 3  Region 2     17600.0
# LoanID_2       2  Product D         Female   Location 6  Region 6         NaN
# LoanID_3       3  Product B           Male   Location 8  Region 3     16600.0
# LoanID_4       4  Product A           Male  Location 26  Region 2     17600.0
# LoanID_5       5  Product B         Female  Location 34  Region 3     21250.0
#
#            StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  AmtPaid60  \
# StringID
# LoanID_1  04/07/2018     2200         45          365       3221       4166
# LoanID_2  02/01/2019     2200         45          365       3161       4096
# LoanID_3  08/12/2016     1000         45          365       2260       3205
# LoanID_4         NaN     2200         45          365       3141       4166
# LoanID_5  28/10/2017     2200         55          365       3570       4745
#
# ...

# %%
lending_co_data.Product
# Out:
# StringID
# LoanID_1       Product B
# LoanID_2       Product D
# LoanID_3       Product B
# LoanID_4       Product A
# LoanID_5       Product B
#                  ...
# LoanID_1039    Product B
# LoanID_1040    Product A
# LoanID_1041    Product A
# LoanID_1042    Product B
# LoanID_1043    Product A
# Name: Product, Length: 1043, dtype: object

# %%
lending_co_data.Location
# Out:
# StringID
# LoanID_1        Location 3
# LoanID_2        Location 6
# LoanID_3        Location 8
# LoanID_4       Location 26
# LoanID_5       Location 34
#                   ...
# LoanID_1039    Location 73
# LoanID_1040    Location 82
# LoanID_1041    Location 11
# LoanID_1042    Location 26
# LoanID_1043    Location 94
# Name: Location, Length: 1043, dtype: object

# %%
lending_co_data['Deposit']
# Out:
# StringID
# LoanID_1       2200
# LoanID_2       2200
# LoanID_3       1000
# LoanID_4       2200
# LoanID_5       2200
#                ...
# LoanID_1039    2200
# LoanID_1040    2200
# LoanID_1041    2200
# LoanID_1042    1000
# LoanID_1043    2200
# Name: Deposit, Length: 1043, dtype: int64

# %%
type(lending_co_data['Deposit'])
# Out:
# pandas.core.series.Series

# %%
lending_co_data[['Deposit']]
# Out:
#              Deposit
# StringID
# LoanID_1        2200
# LoanID_2        2200
# LoanID_3        1000
# LoanID_4        2200
# LoanID_5        2200
# ...              ...
# LoanID_1039     2200
# LoanID_1040     2200
# LoanID_1041     2200
# LoanID_1042     1000
# LoanID_1043     2200
#
# [1043 rows x 1 columns]

# %%
#nested list containing a single element
type(lending_co_data[['Deposit']])
# Out:
# pandas.core.frame.DataFrame

# %%
lending_co_data[['Deposit','Location']].head()
# Out:
#           Deposit     Location
# StringID
# LoanID_1     2200   Location 3
# LoanID_2     2200   Location 6
# LoanID_3     1000   Location 8
# LoanID_4     2200  Location 26
# LoanID_5     2200  Location 34

# %%
prod_loc = ['Product','Location']
lending_co_data[prod_loc].head()
# Out:
#             Product     Location
# StringID
# LoanID_1  Product B   Location 3
# LoanID_2  Product D   Location 6
# LoanID_3  Product B   Location 8
# LoanID_4  Product A  Location 26
# LoanID_5  Product B  Location 34

# %%
lending_co_data[['TotalDaysYr']].head()
# Out:
#           TotalDaysYr
# StringID
# LoanID_1          365
# LoanID_2          365
# LoanID_3          365
# LoanID_4          365
# LoanID_5          365

# %% [markdown]
# <a href="https://colab.research.google.com/github/MANOJKUMARKONDURU/05_Machine-Learning_Nov10_2025/blob/main/02_Series/03_Using_an_Index.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #3.Using an Index in python

# %%
import pandas as pd

# %%
prices_per_catagory = {"Product A": 21000, "Product B": 27000, "Product C": 13000}
prices_per_catagory
# Out:
# {'Product A': 21000, 'Product B': 27000, 'Product C': 13000}

# %%
type(prices_per_catagory)
# Out:
# dict

# %%
#convert to series
prices_per_catagory = pd.Series(prices_per_catagory)
prices_per_catagory
# Out:
# Product A    21000
# Product B    27000
# Product C    13000
# dtype: int64

# %% [markdown]
# __________	0
#
# Product A	21000
#
# Product B	27000
#
# Product C	13000
#
#
# dtype: int64
#
#
# index values - data points

# %%
type(prices_per_catagory)
# Out:
# pandas.core.series.Series

# %%
#to get indices
prices_per_catagory.index
# Out:
# Index(['Product A', 'Product B', 'Product C'], dtype='object')

# %% [markdown]
# #Cruicial points to remember
#
# #1-
#
# An index - a set of values in a sequenced order
#
# #2-
# access through index
#
# #3-
# index will speedup the computations

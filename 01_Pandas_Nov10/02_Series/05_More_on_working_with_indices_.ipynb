# %% [markdown]
# <a href="https://colab.research.google.com/github/MANOJKUMARKONDURU/05_Machine-Learning_Nov10_2025/blob/main/01_Pandas_Nov10/02_Series/05_More_on_working_with_indices_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #5More on working with indices in python

# %%
import pandas as pd

# %%
series_a = pd.Series([10, 20, 30, 40])
prices_per_catagory = pd.Series({"Product A": 21000, "Product B": 27000, "Product C": 13000})

# %%
series_a
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
print(series_a[1])
# Out:
# 20

# %% [markdown]
# #explicit index

# %%
prices_per_catagory
# Out:
# Product A    21000
# Product B    27000
# Product C    13000
# dtype: int64

# %%
print(prices_per_catagory['Product A'])
# Out:
# 21000

# %%
print(prices_per_catagory[1])
# Out:
# 27000
# /tmp/ipython-input-3974018624.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(prices_per_catagory[1])

# %%
series_b = pd.Series([10, 20, 30, 40, 50], index = [1, 2, 3, 4, 5])
series_b
# Out:
# 1    10
# 2    20
# 3    30
# 4    40
# 5    50
# dtype: int64

# %%
series_b[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1683817182.py in <cell line: 0>()
# ----> 1 series_b[0]
#
# ...

# %%
print(series_b[1])
# Out:
# 10

# %%
series_c = pd.Series([10, 20, 30, 40, 50], index = ['1','2', '3', '4', '5'])

series_c
# Out:
# 1    10
# 2    20
# 3    30
# 4    40
# 5    50
# dtype: int64

# %%
print(series_c[1])
# Out:
# 20
# /tmp/ipython-input-147130775.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(series_c[1])

# %%
print(series_c['1'])
# Out:
# 10

# %%
print(series_c[0])
# Out:
# 10
# /tmp/ipython-input-2434070589.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(series_c[0])

# %%
prices_per_catagory
# Out:
# Product A    21000
# Product B    27000
# Product C    13000
# dtype: int64

# %% [markdown]
# #axis labels = label-based indexing

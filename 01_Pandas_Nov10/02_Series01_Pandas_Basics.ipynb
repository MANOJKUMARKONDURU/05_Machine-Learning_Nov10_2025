# %% [markdown]
# <a href="https://colab.research.google.com/github/MANOJKUMARKONDURU/05_Machine-Learning_Nov10_2025/blob/main/02_Series/01_Pandas_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Intro to pandas
#
# open source library
#
# easy to use data structures and data analysis tools for Python programming language
#
# derivered from **panel data** -> **pandas**
#
# built on top of numpy
#
# **most of the work will be done with the help of two high performance and easy to use data structures - 1)series, 2) Dataframe**

# %% [markdown]
# #Series
# single column data - 1D array(numpy)
#
# #DataFrame
# Multicolumn data - 2D array(numpy)

# %% [markdown]
# #what Pandas will do
# data analysis much faster
#
# can import or export files(.csv, .json, etc)
#
#
# **Numpys-** best for numerical calculations
#
# **pandas**- Best for analysing dataset containing multiple types of information.eg:numbers, strings, date and time etc

# %% [markdown]
# shouldn't mix datatypes in rows and columns
#
# a row should have only strings or integers or float- if not will lead to confuse

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
products = ['A', 'B', 'C', 'D']
products
# Out:
# ['A', 'B', 'C', 'D']

# %%
type(products)
# Out:
# list

# %%
#turn list into series
product_categories = pd.Series(products)

# %%
product_categories
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# dtype: object

# %% [markdown]
# type of data stored in series  - object- is not numerical

# %%
type(product_categories) # to see type
# Out:
# pandas.core.series.Series

# %%
type(pd.Series(products))
# Out:
# pandas.core.series.Series

# %%
daily_rate_dollars = pd.Series([100, 21, 27, 35])

daily_rate_dollars
# Out:
# 0    100
# 1     21
# 2     27
# 3     35
# dtype: int64

# %% [markdown]
# the data type - int

# %%
print(daily_rate_dollars)
# Out:
# 0    100
# 1     21
# 2     27
# 3     35
# dtype: int64

# %%
import numpy as np

# %%
array_a = np.array([10, 20, 30, 40, 50])
array_a
# Out:
# array([10, 20, 30, 40, 50])

# %%
#to check the type of the object
type(array_a)
# Out:
# numpy.ndarray

# %%
series_a = pd.Series(array_a)
series_a
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
print(series_a)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
#to check the type of the object
type(series_a)
# Out:
# pandas.core.series.Series

# %% [markdown]
# #Take aways
# #1 -
#    The pandas series is something like powerful version of list, or an enchanved version of the numpy array.
#
# #2-
# Remember to always maintain  **data consistency** (nevver mix different data types)
